# %% [markdown]
# <a href="https://colab.research.google.com/github/nuradilahrozman/Data-Science-Project/blob/main/UploadingLocalFile_YP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_json('https://raw.githubusercontent.com/yash240990/Python/master/simple.json')
data
# Out:
#      id   name  math  physics  chemistry
# 0  A001    Tom    60       66         61
# 1  A002  James    89       76         51
# 2  A003  Jenny    79       90         78

# %%
# upload local files in colab
from google.colab import files
uploaded = files.upload()      # files selection wizard
# Out:
#      <input type="file" id="files-52fb11b7-511f-4c9d-9000-889f6c303d0a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52fb11b7-511f-4c9d-9000-889f6c303d0a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('MOCK_DATA.csv')
data
# Out:
#        id first_name   last_name                       email  gender  \
# 0       1  Hildagard       Hymer  hhymer0@chicagotribune.com  Female
# 1       2   Bellanca      Syvret  bsyvret1@elegantthemes.com  Female
# 2       3     Burton      Pottes     bpottes2@guardian.co.uk    Male
# 3       4      Ariel      Drioli      adrioli3@imageshack.us    Male
# 4       5     Arline     Luparti     aluparti4@posterous.com  Female
# ..    ...        ...         ...                         ...     ...
# 995   996       Vera      Coumbe           vcoumbern@home.pl  Female
# 996   997     Willem      Hewkin           whewkinro@cdc.gov    Male
# 997   998     Andris   Shatliffe        ashatlifferp@msn.com    Male
# 998   999        Kai  Litchfield       klitchfieldrq@ucoz.ru  Female
# 999  1000   Philbert     Gaywood      pgaywoodrr@dropbox.com    Male
#
#           department  salary
# 0         Accounting    6252
# 1              Legal    7076
# 2              Legal    5651
# ...
